# %%
import spacy

# %%
nlp = spacy.load("fr_core_news_sm")

# %%
wikitext = nlp("Henri IV, dit « le Grand », né Henri de Bourbon le 13 décembre 1553 à Pau et mort assassiné le 14 mai 1610 à Paris, est roi de Navarre sous le nom de Henri III (de 1572 à 1610), puis roi de France sous le nom de Henri IV (de 1589 à 1610), devenant à ce titre le premier roi de France issu de la maison capétienne de Bourbon. Il cumule ainsi les dignités de roi de France et de Navarre.")

# %%
for word in wikitext.ents:
    print(word.text, word.label_)
# Out:
# Henri IV PER
# Grand » LOC
# Henri de Bourbon PER
# Pau LOC
# Paris LOC
# Navarre LOC
# Henri III PER
# roi de France PER
# Henri IV PER
# roi de France PER
# maison capétienne de Bourbon PER
# roi de France PER
# Navarre LOC

# %%
spacy.explain("LOC")
# Out:
# 'Non-GPE locations, mountain ranges, bodies of water'

# %%
from spacy import displacy

# %%
displacy.render(wikitext, style="ent", jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Henri IV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , dit « le
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grand »
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , né
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Henri de Bourbon
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("evenements-paris-final.csv")

# %%
df
# Out:
#        date                                        commentaire  startDate  \
# 0      -300   arrivée de la tribu gauloise des Parisii dans...     -300.0
# 1       -53   grand conseil des Gaules en présence de Jules...      -53.0
# 2     14-37                                                NaN       14.0
# 3    50-100                                                NaN       50.0
# 4     65-66                                                NaN       65.0
# ..      ...                                                ...        ...
# 493    2015                                                NaN     2015.0
# 494    2016                                                NaN     2016.0
# 495    2017                                                NaN     2017.0
# 496   <time   datetime="2018" data-sort-value="2018" class=...        NaN
# 497    2019                                                NaN     2019.0
#
#      endDate                                          evenement
# ...

# %%
str = ""
for index, row in df.iterrows():
    str = str + " " + row["evenement"]

# %%
str
# Out:
# ' Premières monnaies d’or des Parisii. <time datetime="U-0051-05" data-sort-value="U-0051-05" class="date-lien">mai</time>\xa0: bataille de Lutèce qui voit la victoire des légions de Labienus, lieutenant de Jules César, sur les Aulerques, les Sénons et les Parisii de Camulogène. Ces derniers occupent le site depuis plusieurs siècles. Les Gaulois préfèrent détruire les ponts et incendier eux-mêmes leur cité plutôt que d’y laisser entrer les Romains. L’incendie de la Lutèce gauloise permettra aux Romains de doter la ville d’une structure romaine rapidement, d’autant qu’avec sept collines et un fleuve, le parallèle avec Rome est facile. Les nautes de Lutèce élèvent une colonne en l’honneur de Jupiter\xa0: c’est le fameux «\xa0pilier des Nautes\xa0» mis au jour sous les fondations de Notre-Dame. Construction du forum de Lutèce. Construction à Lutèce de trois thermes alimentées par un aqueduc de 16 kilomètres longeant la Bièvre dont les thermes de Lutèce, d’un amphithéâtre de 17\xa0000 pl
# ...

# %%
textnlp = nlp(str)

# %%
for word in textnlp.ents:
    print(word.text, word.label_)
# Out:
# Parisii MISC
# class="date LOC
# bataille de Lutèce MISC
# Labienus PER
# Jules César PER
# Aulerques LOC
# Sénons LOC
# Parisii LOC
# Camulogène LOC
# Gaulois LOC
# Romains LOC
# Lutèce LOC
# Romains LOC
# Rome LOC
# Lutèce LOC
# Jupiter  PER
# c’ MISC
# Nautes » LOC
# Notre LOC
# Lutèce LOC
# Lutèce LOC
# la Bièvre LOC
# Lutèce LOC
# Lutèce LOC
# Martyre LOC
# Lutèce LOC
# saint Denis PER
# Gaule LOC
# colline de Montmartre LOC
# saint Denis PER
# la France LOC
# Saccage PER
# La Seine LOC
# Lutèce LOC
# Saint PER
# Étienne MISC
# Parisiens LOC
# Notre-Dame LOC
# Childebert Ier PER
# césar Julien MISC
# Paris LOC
# Alamans MISC
# Francs MISC
# Julien PER
# Paris LOC
# île de la Cité LOC
# L'empereur PER
# Danube LOC
# Julien PER
# Auguste PER
# Paris LOC
# Constance II PER
# Misopogon Julien MISC
# Lutèce LOC
# Change LOC
# petit Pont LOC
# Concile MISC
# Paris LOC
# Arius PER
# concile de Nicée MISC
# goths MISC
# burgondes MISC
# l’ MISC
# s’ MISC
# l'Europe LOC
# Paris LOC
# ...

# %%
displacy.render(textnlp, style="ent", jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"> Premières monnaies d’or des
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Parisii
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# . &lt;time datetime=&quot;U-0051-05&quot; data-sort-value=&quot;U-0051-05&quot;
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     class=&quot;date
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# -lien&quot;&gt;mai&lt;/time&gt; :
# ...

# %%
personnalites = []
for word in textnlp.ents:
    if(word.label_ == "PER"):
        pers = {}
        pers["nom"] = word.text
        personnalites.append(pers)

# %%
personnalites
# Out:
# [{'nom': 'Labienus'},
#  {'nom': 'Jules César'},
#  {'nom': 'Jupiter\xa0'},
#  {'nom': 'saint Denis'},
#  {'nom': 'saint Denis'},
#  {'nom': 'Saccage'},
#  {'nom': 'Saint'},
#  {'nom': 'Childebert Ier'},
#  {'nom': 'Julien'},
#  {'nom': "L'empereur"},
#  {'nom': 'Julien'},
#  {'nom': 'Auguste'},
#  {'nom': 'Constance II'},
#  {'nom': 'Arius'},
#  {'nom': 'Valentinien'},
#  {'nom': 'class="abbr'},
#  {'nom': 'Valentinien'},
#  {'nom': 'class="abbr'},
#  {'nom': 'Procope'},
#  {'nom': 'Valens'},
#  {'nom': 'Jovin'},
#  {'nom': 'Magnus Maximus'},
#  {'nom': 'Gratien'},
#  {'nom': 'saint Martin'},
#  {'nom': 'Attila'},
#  {'nom': 'Childéric'},
#  {'nom': 'class="abbr'},
#  {'nom': 'saint Denis'},
#  {'nom': 'Sainte Geneviève'},
#  {'nom': 'Clovis'},
#  {'nom': 'Clovis'},
#  {'nom': 'Syagrius'},
#  {'nom': 'sainte Geneviève'},
#  {'nom': 'Sainte Geneviève'},
#  {'nom': 'Clovis'},
#  {'nom': 'Clovis'},
#  {'nom': 'sainte Geneviève'},
#  {'nom': 'Clovis'},
#  {'nom': 'Syagrius'},
# ...
